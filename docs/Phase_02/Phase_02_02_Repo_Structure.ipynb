# %% [markdown]
# ---
#
# ## Phase 2 — Repo Structure (Aligned Current Project)
#
# ```text
# DAY_83_PROFESSIONAL_PORTFOLIO_PROJECT_PYTHON_.../
# │
# ├── .gitignore
# ├── README.md
# ├── requirements.txt
# │
# ├── app/
# │   ├── app.py
# │   ├── config.py
# │   │
# │   ├── database/
# │   │   └── portfolio.db              # exists (Phase 2: do not depend on it)
# │   │
# │   ├── models/
# │   │   └── models.py                 # exists (Phase 2: do not require it)
# │   │
# │   ├── data/                         # ADD (Phase 2 dataset lives here)
# │   │   ├── __init__.py
# │   │   └── projects.py               # in-memory list/dict of projects
# │   │
# │   ├── static/
# │   │   ├── css/
# │   │   │   └── styles.css            # baseline typography/spacing
# │   │   ├── images/
# │   │   │   ├── profile/              # optional
# │   │   │   └── projects/             # optional
# │   │   └── js/
# │   │       └── main.js               # optional (can be empty)
# │   │
# │   └── templates/
# │       ├── base.html
# │       ├── index.html                # your home template
# │       ├── about.html
# │       ├── projects.html
# │       ├── project_detail.html
# │       ├── contact.html
# │       └── 404.html                  # ADD (clean invalid slug behavior)
# │
# ├── docs/
# │   ├── 00__A__Web_Dev_Reference_Map.ipynb
# │   ├── 00__B__Initial_Brainstorm_Roadmap.ipynb
# │   └── 00__C__Full_Phase_Breakdown.ipynb
# │
# ├── Phase_1/
# │   ├── Phase_1_01_Starting_Doc.ipynb
# │   └── Phase_1_02_Projects_Map_Classification.ipynb
# │
# ├── Phase_2/
# │   └── Phase_2_01_Starting_Doc.ipynb
# │
# ├── Phase_3/
# ├── Phase_4/
# ├── Phase_5/
# ├── Phase_6/
# ├── Phase_7/
# ├── Phase_8/
# └── Phase_9/
# ```
#
# ---
#
# ## What changes from your current structure (minimal, Phase 2 only)
#
# ### Add these (Phase 2 required)
#
# 1. `app/data/`
# 2. `app/data/projects.py`
# 3. `app/templates/404.html`
#
# ### Keep these as-is (Phase 2 uses them)
#
# * `app/app.py`
# * `app/config.py`
# * `app/templates/*.html`
# * `app/static/css/styles.css` (if you already have it, keep; if not, create)
#
# ### Leave these alone (they exist, but Phase 2 doesn’t depend on them yet)
#
# * `app/database/portfolio.db`
# * `app/models/models.py`
#
# They can stay. Phase 2 just won’t require them to run.
#
# ---
#
# ## Phase 2 Mapping (Your structure → the outline you’re following)
#
# ### 1) Application foundation
#
# * **1.1** Flask init + config → `app/app.py`, `app/config.py`
# * **1.2** Core routes → `app/app.py`
# * **1.3** Dependencies → `requirements.txt`
# * **1.4** Local run reliability → confirmed by running app and loading all routes
#
# ### 2) Template system
#
# * **2.1** base layout → `app/templates/base.html`
# * **2.2** inheritance across all pages → `index/about/projects/contact/project_detail` all extend base
# * **2.3** shared components (optional)
#   In your structure, we do **one** of these:
#
#   * Option A (keep simple): navbar/footer inside `base.html`
#   * Option B (still clean): create `app/templates/partials/` and include them
#     (not required by your current tree, so I’m not forcing it)
# * **2.4** page templates → already present in `app/templates/`
#
# ### 3) MVP UI styling
#
# * **3.1–3.4** → `app/static/css/styles.css`, plus optional images/js folders you already have
#
# ### 4) Projects hub (key Phase 2 feature)
#
# * **4.1** temporary dataset → `app/data/projects.py`
# * **4.2** render cards via loop → `app/templates/projects.html`
# * **4.3** sorting logic → `app/app.py` (route logic)
# * **4.4** filtering by primary_category → `app/app.py` using query params or dedicated routes
# * **4.5** dedicated category pages → `/projects/web`, `/projects/data`, `/projects/software`
# * **4.6** featured projects on home → `index.html` pulls `featured=True` items
#
# ### 5) Project detail pages
#
# * **5.1** route `/projects/<slug>` → `app/app.py`
# * **5.2** detail template → `app/templates/project_detail.html`
# * **5.3** back navigation → link in `project_detail.html`
#
# ### 7) Outputs
#
# * Site runs locally, all routes work, projects hub behavior works, UI baseline readable
#
# ---
#
# ## The one discipline rule for Phase 2 (based on your repo)
#
# All “project content” must live in:
#
# * `app/data/projects.py`
#
# Not in templates, not scattered in routes, not mixed into models yet.
#
# That single decision will keep Phase 2 clean and make Phase 3 (DB) painless.
#
# ---
#
# If you want the next step immediately: I can give you the **exact starter contents** for:
#
# * `app/data/projects.py` (schema-complete, with 2–3 example projects)
# * the updated `app/app.py` routes implementing sort/filter/category/detail
# * a minimal `404.html`
#
# (all in one copy/paste block per file).
